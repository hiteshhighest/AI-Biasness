# %% [markdown]
# ## Data Exploration

# %% [markdown]
# We will explore the recruitment dataset before training our model.

# %% [markdown]
# Importing the required library for exploring the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# The recruitment dataset is loaded from the raw data directory using Pandas.

# %%
df = pd.read_csv("../data/raw/recruitment.csv")

# %%
df.head()
# Out:
#    Candidate_ID  Gender  Age Education_Level  Experience_Years  Skill_Score  \
# 0             1    Male   50       Bachelors                19           48
# 1             2   Other   36       Bachelors                18            9
# 2             3  Female   58         Masters                11            1
# 3             4    Male   48         Masters                 0           74
# 4             5    Male   37       Bachelors                 0           64
#
#    Aptitude_Test_Score  Technical_Test_Score  Communication_Score  \
# 0                   75                    70                   65
# 1                   53                    46                   25
# 2                   85                    62                   72
# 3                   35                    79                   67
# 4                   99                    25                   38
#
#    Certifications_Count  Previous_Companies  Interview_Score    Location  \
# ...
